# %%
from PIL import Image
import tensorflow as tf
import tensorflow_addons as tfa
import os
import matplotlib.pyplot as plt
import numpy as np

os.environ["JUPYTER_PATH"] = "/home/ubuntu/repositories/sudoku-ml-vision-app"
os.system("echo $JUPYTER_PATH")
print(os.getcwd())
# Out:
# 2022-12-11 18:45:31.211657: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-11 18:45:31.351770: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-11 18:45:31.351793: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-11 18:45:32.206996: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-11 18:45:32.207076: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-11 18:45:32.207087: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# /home/ubuntu/repositories/sudoku-ml-vision-app
# /home/ubuntu/repositories/sudoku-ml-vision-app/ml/01_processing

# %%
tf_train_image_data_local = '/home/ubuntu/repositories/sudoku-ml-vision-app/temporary/train_tf'
tf_train_rotated_image_data_local = '/home/ubuntu/repositories/sudoku-ml-vision-app/temporary/rotated_train_tf'
tf_train_blanked_image_data_local = '/home/ubuntu/repositories/sudoku-ml-vision-app/temporary/blank_train_tf'

# %%
image_data_train = tf.data.Dataset.load(tf_train_image_data_local)

tf_train_rotated_image_data = tf.data.Dataset.load(tf_train_rotated_image_data_local)

tf_train_blanked_image_data = tf.data.Dataset.load(tf_train_blanked_image_data_local)
# Out:
# 2022-12-11 18:45:39.085635: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-12-11 18:45:39.085668: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-12-11 18:45:39.085692: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ip-172-31-16-248): /proc/driver/nvidia/version does not exist
# 2022-12-11 18:45:39.085907: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# listify original train data
for image_batch, label_batch in image_data_train.as_numpy_iterator():
    pass
    
# listify original map-rotated train data
for image_rotated_batch, label_rotated_batch in tf_train_rotated_image_data.as_numpy_iterator():
    pass

# listify original map-rotated train data
for image_blank_batch, label_blank_batch in tf_train_blanked_image_data.as_numpy_iterator():
    pass

# %%
sample_index = 5

sample_image = image_batch[sample_index,:,:,:].astype(int)
sample_rotated_image = image_rotated_batch[sample_index,:,:,:].astype(int)
sample_blank_image = image_blank_batch[sample_index,:,:,:].astype(int)

# %%
plt.title("Image from original train with shape {}".format(sample_image.shape))
_ = plt.imshow(sample_image)

# %%
plt.title("Image from rotated train with shape {}".format(sample_rotated_image.shape))
_ = plt.imshow(sample_rotated_image)

# %%
sample_blank_index = 9

sample_blank_image = image_blank_batch[sample_blank_index,:,:,:].astype(int)

plt.title("Image from blank train with shape {}".format(sample_blank_image.shape))
_ = plt.imshow(sample_blank_image)

# %%
sample_blank_label = label_blank_batch[sample_blank_index]
sample_blank_label
# Out:
# 0

# %%
tf_train_rotated_image_data.filter(lambda x,y: y != 0)
# Out:
# WARNING:tensorflow:From /home/ubuntu/repositories/sudoku-ml-vision-app/.venv/lib/python3.10/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 tf_train_rotated_image_data.filter(lambda x,y: y != 0)
#
# File ~/repositories/sudoku-ml-vision-app/.venv/lib/python3.10/site-packages/tensorflow/python/data/ops/dataset_ops.py:2519, in DatasetV2.filter(self, predicate, name)
#    2516 # Loaded lazily due to a circular dependency (dataset_ops -> filter_op ->
#    2517 # dataset_ops).
#    2518 from tensorflow.python.data.ops import filter_op  # pylint: disable=g-import-not-at-top
# -> 2519 return filter_op.filter(self, predicate, name)
#
# File ~/repositories/sudoku-ml-vision-app/.venv/lib/python3.10/site-packages/tensorflow/python/data/ops/filter_op.py:25, in filter(self, predicate, name)
#      24 def filter(self, predicate, name=None):  # pylint: disable=redefined-builtin
# ---> 25   return FilterDataset(self, predicate, name=name)
#
# File ~/repositories/sudoku-ml-vision-app/.venv/lib/python3.10/site-packages/tensorflow/python/data/ops/filter_op.py:45, in FilterDataset.__init__(self, input_dataset, predicate, use_legacy_function, name)
#      38 wrapped_func = structured_function.StructuredFunctionWrapper(
#      39     predicate,
#      40     self._transformation_name(),
#      41     dataset=input_dataset,
#      42     use_legacy_function=use_legacy_function)
#      43 if not wrapped_func.output_structure.is_compatible_with(
#      44     tensor_spec.TensorSpec([], dtypes.bool)):
# ---> 45   raise ValueError(f"Invalid `predicate`. `predicate` must return a "
#      46                    f"`tf.bool` scalar tensor, but its return type is "
#      47                    f"{wrapped_func.output_structure}.")
#      48 self._predicate = wrapped_func
#      49 self._name = name
#
# ValueError: Invalid `predicate`. `predicate` must return a `tf.bool` scalar tensor, but its return type is TensorSpec(shape=(None,), dtype=tf.bool, name=None).
