# %%
from PIL import Image
import os
import cv2
import sys
sys.path.append('../..')

# %%
from app.parse_image_service.parse_image_utils import (
    preprocess_image,
    extract_grid_cell_patches
)

LOCAL_TEMP_DIR = '/home/ubuntu/repositories/sudoku-ml-vision-app/temporary'

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-1.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=199x215>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-2.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=200x189>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-3.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=420x408>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-4.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=224x227>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-5.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=261x231>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-6.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=244x230>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-7.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=435x395>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-8.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=493x403>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-9.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=574x404>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-10.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=536x416>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-11.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=315x304>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-12.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=327x307>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-13.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=314x301>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-14.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=332x344>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-15.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=417x394>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-16.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=448x397>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-17.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=426x417>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-18.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=438x427>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-19.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=340x333>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-20.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=337x342>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-21.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=352x342>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-22.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=357x337>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-23.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=462x491>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-24.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=297x327>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-25.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=279x328>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-26.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=285x329>

# %%
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-27.PNG'
sample_image = Image.open(sample_image_path)
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=348x344>
