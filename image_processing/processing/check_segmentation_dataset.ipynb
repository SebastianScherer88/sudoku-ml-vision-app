# %%
from PIL import Image
import os
import cv2
from parse_image_utils import (
    preprocess_image,
    extract_grid_cell_patches
)

LOCAL_TEMP_DIR = '/home/ubuntu/repositories/sudoku-ml-vision-app/temporary'

# %%
sample_image_index = 11 # 1,...,27
sample_image_path = f'{LOCAL_TEMP_DIR}/sudoku-grid-images/manual-extracts/grid-{sample_image_index}.PNG'

# %%
sample_image = Image.open(sample_image_path)

# %%
sample_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=315x304>

# %%
sudoku_image = cv2.imread(sample_image_path)

preprocessed_sudoku_image = preprocess_image(sudoku_image)

_, _, image_patches, _ = extract_grid_cell_patches(preprocessed_sudoku_image)

# %%
len(image_patches)
# Out:
# 81

# %%
patch_1_array = image_patches[0]
patch_1_array.shape
# Out:
# (100, 100)

# %%
patch_1_image = Image.fromarray(patch_1_array)
patch_1_image
# Out:
# <PIL.Image.Image image mode=L size=100x100>
